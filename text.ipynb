# %%
import sqlite3

# Connect to database (creates file if not exists)
conn = sqlite3.connect('products.db')
cursor = conn.cursor()

# Create table
cursor.execute('''
CREATE TABLE IF NOT EXISTS products (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    name TEXT NOT NULL,
    sku TEXT UNIQUE,
    brand TEXT,
    category TEXT,
    price REAL NOT NULL,
    quantity INTEGER DEFAULT 0,
    description TEXT,
    created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
)
''')

conn.commit()
conn.close()

print("Database and table created successfully.")
# Out:
# Database and table created successfully.

# %%
import sqlite3

conn = sqlite3.connect('products.db')
cursor = conn.cursor()

sample_product = (
    'Conical Flask 500ml',   # name
    'COR-FL-500',            # sku
    'Corning',               # brand
    'Glassware',             # category
    220.0,                   # price
    15,                      # quantity
    'Borosilicate glass flask with narrow neck'
)

cursor.execute('''
INSERT INTO products (name, sku, brand, category, price, quantity, description)
VALUES (?, ?, ?, ?, ?, ?, ?)
''', sample_product)

conn.commit()
conn.close()

print("Sample product inserted successfully.")
# Out:
# Sample product inserted successfully.

# %%
import sqlite3

conn = sqlite3.connect('products.db')
cursor = conn.cursor()


products = [
    ('Beaker 100ml', 'COR-BE-100', 'Corning', 'Glassware', 120.0, 30, 'Borosilicate beaker'),
    ('Beaker 250ml', 'COR-BE-250', 'Corning', 'Glassware', 150.0, 25, 'Standard lab beaker'),
    ('Conical Flask 250ml', 'COR-FL-250', 'Corning', 'Glassware', 200.0, 20, 'Erlenmeyer flask'),
    ('Test Tube 15ml', 'COR-TT-015', 'Corning', 'Glassware', 50.0, 100, 'Clear test tube'),
    ('Petri Dish 90mm', 'COR-PD-090', 'Corning', 'Plasticware', 80.0, 60, 'Sterile petri dish'),
    ('Micropipette 100-1000µl', 'COR-MP-1000', 'Corning', 'Instruments', 2500.0, 10, 'Adjustable pipette'),
    ('Centrifuge Tube 50ml', 'COR-CT-050', 'Corning', 'Plasticware', 25.0, 200, 'Falcon tube'),
    ('Glass Slide', 'COR-GS-001', 'Corning', 'Glassware', 10.0, 500, 'Microscope slide'),
    ('Cover Slip', 'COR-CS-001', 'Corning', 'Glassware', 5.0, 500, 'Thin glass cover')
]

cursor.executemany('''
INSERT INTO products (name, sku, brand, category, price, quantity, description)
VALUES (?, ?, ?, ?, ?, ?, ?)
''', products)

conn.commit()
conn.close()

print("Multiple products inserted successfully.")
# Out:
# Multiple products inserted successfully.
